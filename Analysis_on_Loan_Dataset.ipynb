# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# !pip install pandas

# %%
df=pd.read_csv("loan_data_set.csv",sep=",",header=0)
df
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
df.describe()
# Out:
#        ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# count       614.000000         614.000000  592.000000         600.00000
# mean       5403.459283        1621.245798  146.412162         342.00000
# std        6109.041673        2926.248369   85.587325          65.12041
# min         150.000000           0.000000    9.000000          12.00000
# 25%        2877.500000           0.000000  100.000000         360.00000
# 50%        3812.500000        1188.500000  128.000000         360.00000
# 75%        5795.000000        2297.250000  168.000000         360.00000
# max       81000.000000       41667.000000  700.000000         480.00000
#
#        Credit_History
# count      564.000000
# mean         0.842199
# std          0.364878
# min          0.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max          1.000000

# %%
df.dtypes
# Out:
# Loan_ID               object
# Gender                object
# Married               object
# Dependents            object
# Education             object
# Self_Employed         object
# ApplicantIncome        int64
# CoapplicantIncome    float64
# LoanAmount           float64
# Loan_Amount_Term     float64
# Credit_History       float64
# Property_Area         object
# Loan_Status           object
# dtype: object

# %%
df["Gender"].value_counts()
# Out:
# Male      489
# Female    112
# Name: Gender, dtype: int64

# %%
df["Loan_Status"].value_counts()
# Out:
# Y    422
# N    192
# Name: Loan_Status, dtype: int64

# %%
df["Loan_Status"].value_counts(normalize=True)*100
# Out:
# Y    68.729642
# N    31.270358
# Name: Loan_Status, dtype: float64

# %%
df["Loan_Status"].value_counts().plot(kind="pie")
# Out:
# <AxesSubplot:ylabel='Loan_Status'>

# %%
df["ApplicantIncome"].plot(kind="hist")
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df["LoanAmount"].plot(kind="hist")
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
pd.crosstab(df["Gender"],df["Loan_Status"],margins=True)
# Out:
# Loan_Status    N    Y  All
# Gender
# Female        37   75  112
# Male         150  339  489
# All          187  414  601

# %%
(pd.crosstab(df["Gender"],df["Loan_Status"],margins=True,normalize="index")*100).plot(kind="bar")
# Out:
# <AxesSubplot:xlabel='Gender'>

# %%
pd.crosstab(df["Credit_History"],df["Loan_Status"]).plot(kind="bar")
# Out:
# <AxesSubplot:xlabel='Credit_History'>

# %%
x=df.corr()
sns.heatmap(x,annot=True)
# Out:
# <AxesSubplot:>

# %%
df.boxplot(column="ApplicantIncome",by="Gender")
# Out:
# <AxesSubplot:title={'center':'ApplicantIncome'}, xlabel='Gender'>

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.drop_duplicates()
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
df.isnull().sum()
# Out:
# Loan_ID               0
# Gender               13
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# Applicant_in_USD      0
# dtype: int64

# %%
df["Gender"].mode()[0]
# Out:
# 'Male'

# %%
df["Gender"]=df["Gender"].fillna(df["Gender"].mode()[0])

# %%
df["LoanAmount"].median()
# Out:
# 128.0

# %%
df["LoanAmount"]=df["LoanAmount"].fillna(df["LoanAmount"].median())

# %%
df["Total_Income"]=df["ApplicantIncome"]+df["CoapplicantIncome"]

# %%
df["Ratio"]=df["LoanAmount"]/df["Total_Income"]*100

# %%
df["Ratio"].describe()
# Out:
# count    614.000000
# mean       2.387679
# std        0.870716
# min        0.252292
# 25%        1.922055
# 50%        2.412921
# 75%        2.815802
# max        8.271164
# Name: Ratio, dtype: float64

# %%
def income_grp(pi):
    if pi<5000:
        group="Low Income"
    elif pi>5000 and pi<10000:
        group="Mid Income"
    else :
        group="High Income"
    return group

# %%
df["Binning"]=df["Total_Income"].apply(income_grp)

# %%
def grp(row):
    if(row["Married"]=="Yes") and (row["Education"]=="Graduate") and (row["Self_Employed"]=="No"):
       group="stable"
    else:
       group="Unstable"
    return group

# %%
df["group"]=df.apply(grp,axis=1)

# %%
df.to_csv("Updated_loan.csv")

# %%
df.groupby(['Education','Gender']).agg({'LoanAmount':'mean','ApplicantIncome':'max'})
# Out:
#                      LoanAmount  ApplicantIncome
# Education    Gender
# Graduate     Female  129.815217            19484
#              Male    158.801546            81000
# Not Graduate Female  112.550000            18165
#              Male    120.026316             7667

# %%
q=df.loc[df['Education']=='Graduate']
q.sort_values(by='ApplicantIncome',ascending=False)[:3]
# Out:
#       Loan_ID Gender Married Dependents Education Self_Employed  \
# 409  LP002317   Male     Yes         3+  Graduate            No
# 333  LP002101   Male     Yes          0  Graduate           NaN
# 171  LP001585   Male     Yes         3+  Graduate            No
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 409            81000                0.0       360.0             360.0
# 333            63337                0.0       490.0             180.0
# 171            51763                0.0       700.0             300.0
#
#      Credit_History Property_Area Loan_Status  Applicant_in_USD  Total_Income  \
# 409             0.0         Rural           N        986.241325       81000.0
# 333             1.0         Urban           Y        771.179837       63337.0
# 171             1.0         Urban           Y        630.256910       51763.0
#
#         Ratio      Binning     group
# 409  0.444444  High Income    stable
# ...

# %%
var=df.loc[(df['Education']=='Graduate')&(df['Gender']=='Male')]
var.sort_values(by='ApplicantIncome',ascending=False)[:3]
# Out:
#       Loan_ID Gender Married Dependents Education Self_Employed  \
# 409  LP002317   Male     Yes         3+  Graduate            No
# 333  LP002101   Male     Yes          0  Graduate           NaN
# 171  LP001585   Male     Yes         3+  Graduate            No
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 409            81000                0.0       360.0             360.0
# 333            63337                0.0       490.0             180.0
# 171            51763                0.0       700.0             300.0
#
#      Credit_History Property_Area Loan_Status  Applicant_in_USD  Total_Income  \
# 409             0.0         Rural           N        986.241325       81000.0
# 333             1.0         Urban           Y        771.179837       63337.0
# 171             1.0         Urban           Y        630.256910       51763.0
#
#         Ratio      Binning     group
# 409  0.444444  High Income    stable
# ...

# %%
sns.catplot(data=df,x="Loan_Status",kind="count")

# %%
plt.figure(figsize=(10,7))
sns.distplot(df["LoanAmount"],hist=False)
# Out:
# C:\Users\Sushant\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='LoanAmount', ylabel='Density'>

# %%
plt.figure(figsize=(15,5))
sns.histplot(df["LoanAmount"])
# Out:
# <AxesSubplot:xlabel='LoanAmount', ylabel='Count'>

# %%
sns.jointplot(data=df,x="ApplicantIncome",y="LoanAmount",kind="scatter",hue="Gender")

# %%
sns.jointplot(data=df,x="ApplicantIncome",y="LoanAmount",kind="scatter",hue="Education")

# %%
sns.jointplot(data=df,x="ApplicantIncome",y="LoanAmount",kind="scatter",hue="Loan_Status")

# %%
sns.jointplot(data=df,x="ApplicantIncome",y="LoanAmount",kind="reg")

# %%
sns.pairplot(data=df)

# %%
sns.catplot(data=df,x="ApplicantIncome",y="Gender")

# %%
sns.catplot(data=df,x="Gender",y="LoanAmount",kind="box")

# %%
sns.catplot(data=df,x="Gender",y="LoanAmount",kind="swarm")
# Out:
# C:\Users\Sushant\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 31.5% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
sns.catplot(data=df,x="Gender",y="LoanAmount",kind="swarm",hue="Loan_Status")
# Out:
# C:\Users\Sushant\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 31.5% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
sns.catplot(data=df,x="Gender",y="LoanAmount",kind="violin")
